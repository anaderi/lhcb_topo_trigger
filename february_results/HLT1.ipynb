# %%
# %run additional.ipynb

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plotting', 'empty']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
pandas.set_option('display.max_colwidth', 120)

# %% [markdown]
# # HLT1 2-body classifier

# %% [markdown]
# did preselections:
#
# * sv.n == 2,
# * sv.minpt >= 500

# %% [markdown]
# ## Training channels (read data)
#
# We will use all possible

# %%
bck_train_mode_name = 30000000
sig_train_modes_names = list(set(empty_events.keys()) - {bck_train_mode_name})
sig_train_files = ['mod_{}.csv'.format(name) for name in sig_train_modes_names]
bck_train_files = 'mod_30000000.csv'
folder = "Topo/prepared_hlt_body/"

# %%
# concat all signal data
# concat_files(folder, sig_train_files, os.path.join(folder , 'signal_hlt1.csv'))

# %%
signal_data = pandas.read_csv(os.path.join(folder, 'signal_hlt1.csv'), sep='\t')
bck_data = pandas.read_csv(os.path.join(folder, bck_train_files), sep='\t')

# %%
signal_data.columns
# Out:
# Index([u'mode', u'event_number', u'sv_number', u'pass_2body', u'pass_nbody', u'signal', u'sumpt', u'm', u'mcor', u'ipchi2', u'chi2', u'sumipchi2', u'fdr', u'nlt16', u'minpt', u'eta', u'pt', u'nmu', u'n', u'fdchi2', u'maxtchi2', u'ngood', u'nmu1', u'mupt', u'n1trk', u'sig', u'idx'], dtype='object')

# %% [markdown]
# ## Counting events and svrs,
# that passed **L0** and **GoodGenB** preselection (this data was generated by skim)

# %%
print 'Signal', statistic_length(signal_data)
print 'Bck', statistic_length(bck_data)
# Out:
# Signal
# {'SVR': 28773384, 'Events': 560508}
# Bck {'SVR': 408147, 'Events': 38035}

# %%
total_bck_events = statistic_length(bck_data)['Events'] + empty_events[bck_train_mode_name]
total_signal_events_by_mode = dict()
for mode in sig_train_modes_names:
    total_signal_events_by_mode[mode] = statistic_length(signal_data[signal_data['mode'] == mode])['Events'] + empty_events[mode]

# %% [markdown]
# ### events distribution by mode

# %%
print 'Bck:', total_bck_events
'Signal:', total_signal_events_by_mode
# Out:
# Bck: 111306
# ('Signal:',
#  {11102003: 22317,
#   11104121: 21960,
#   11114001: 61102,
#   11114101: 36257,
#   11124001: 0,
#   11296013: 17149,
#   11536011: 13893,
#   11874004: 27212,
#   11874042: 3942,
#   12103035: 25250,
#   12103121: 22180,
#   12165106: 0,
#   12265042: 0,
#   12873002: 9480,
#   12873432: 0,
#   12875500: 0,
#   13102201: 0,
#   13102412: 31938,
#   13104012: 0,
#   13112001: 34736,
#   13144001: 54266,
#   13144020: 39278,
#   13246001: 37313,
#   13264021: 25165,
#   13512010: 43379,
#   13774002: 12589,
#   15164001: 7130,
#   15512011: 27799,
#   20000000: 0,
#   21263002: 8871,
#   23103110: 0,
#   25103000: 0,
#   25103110: 0,
#   27163002: 848,
#   27163400: 380,
#   27265001: 871,
#   27265101: 2192})

# %% [markdown]
# ## Define variables
#
# We will use two sets of variables

# %%
variables_base = ["mcor", "chi2", "pt", "fdchi2", "minpt", "nlt16"]
variables_additional = ["m", "fdr", "sumpt", "sumipchi2", "eta"]

# %% [markdown]
# ## Counting events and svrs,
#
# which passed **pass_nbody** (equivalent Mike's preselections for nbody selection)

# %%
# hlt1 2body selection
signal_data = signal_data[signal_data['pass_2body'] == 1]
bck_data = bck_data[bck_data['pass_2body'] == 1]

# %%
print 'Signal', statistic_length(signal_data)
print 'Bck', statistic_length(bck_data)
# Out:
# Signal
# {'SVR': 1136425, 'Events': 448563}
# Bck {'SVR': 16342, 'Events': 10530}

# %%
total_signal_events_by_mode_presel = dict()
for mode in sig_train_modes_names:
    total_signal_events_by_mode_presel[mode] = statistic_length(signal_data[signal_data['mode'] == mode])['Events']
total_bck_events_presel = statistic_length(bck_data)['Events']

# %% [markdown]
# ### events distribution by mode

# %%
print 'Bck:', total_bck_events_presel
'Signal:', total_signal_events_by_mode_presel
# Out:
# Bck: 10530
# ('Signal:',
#  {11102003: 17011,
#   11104121: 13743,
#   11114001: 53482,
#   11114101: 24344,
#   11124001: 0,
#   11296013: 15993,
#   11536011: 12026,
#   11874004: 22375,
#   11874042: 3163,
#   12103035: 21399,
#   12103121: 2118,
#   12165106: 0,
#   12265042: 0,
#   12873002: 7351,
#   12873432: 0,
#   12875500: 0,
#   13102201: 0,
#   13102412: 18612,
#   13104012: 0,
#   13112001: 28577,
#   13144001: 48350,
#   13144020: 34515,
#   13246001: 33890,
#   13264021: 22094,
#   13512010: 28064,
#   13774002: 10298,
#   15164001: 6336,
#   15512011: 17416,
#   20000000: 0,
#   21263002: 5786,
#   23103110: 0,
#   25103000: 0,
#   25103110: 0,
#   27163002: 458,
#   27163400: 135,
#   27265001: 404,
#   27265101: 623})

# %%
signal_data[:5]
# Out:
#         mode  event_number  sv_number  pass_2body  pass_nbody  signal  \
# 0   13144001             0          0           1           1       1
# 3   13144001             0          3           1           1       1
# 4   13144001             0          4           1           1       1
# 38  13144001             1          3           1           1       1
# 39  13144001             1          4           1           1       1
#
#       sumpt         m     mcor     ipchi2    ...      nmu  n      fdchi2  \
# 0   2919.64  1723.000  4091.68   652.6600    ...        1  2   4673.5800
# 3   2463.47   337.013  1578.69    55.4746    ...        0  2     75.1089
# 4   3237.45  2165.520  4253.02   431.0880    ...        1  2   5344.6800
# 38  4420.88  1645.150  4260.60  2879.8900    ...        1  2   7155.3000
# 39  4498.91  1911.790  4473.97  3625.5800    ...        1  2  19735.2000
#
#     maxtchi2  ngood  nmu1     mupt  n1trk  sig  idx
# 0    1.24344      2     1  1846.81      2    1    0
# 3    1.09587      2     0    -1.00      2    1    3
# 4    1.24344      2     1  1846.81      2    1    4
# 38   1.30690      2     1  3761.62      1    1    3
# 39   1.15761      2     1  3761.62      1    1    4
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Prepare train/test splitting
#
# Divide events which passed alll preselections into two equal parts randomly

# %%
from rep.data import DataStorage
ds_signal = DataStorage(signal_data)
ds_train_signal, ds_test_signal = ds_signal.get_train_test(train_size=0.5, test_size=0.5, 
                                                           random_state=13, group_columns=['mode', 'event_number'])
ds_train_signal = ds_train_signal.get_data()
ds_test_signal = ds_test_signal.get_data()

ds_bck = DataStorage(bck_data)
ds_train_bck, ds_test_bck = ds_bck.get_train_test(train_size=0.5, test_size=0.5, 
                                                  random_state=13, group_columns=['mode', 'event_number'])
ds_train_bck = ds_train_bck.get_data()
ds_test_bck = ds_test_bck.get_data()
# Out:
# /moosefs/notebook/antares/work/REP/rep_core/rep/data/storage.py:15: UserWarning: The data processing pipeline is unstable and it's probably will be changed in the future.
#   "it's probably will be changed in the future.", UserWarning)

# %% [markdown]
# ### train: counting events and svrs

# %%
print 'Signal', statistic_length(ds_train_signal)
print 'Bck', statistic_length(ds_train_bck)
# Out:
# Signal
# {'SVR': 568815, 'Events': 224281}
# Bck {'SVR': 8161, 'Events': 5265}

# %%
train = pandas.concat([ds_train_bck, ds_train_signal])

# %% [markdown]
# ### test: counting events and svrs

# %%
print 'Signal', statistic_length(ds_test_signal)
print 'Bck', statistic_length(ds_test_bck)
# Out:
# Signal
# {'SVR': 567610, 'Events': 224282}
# Bck {'SVR': 8181, 'Events': 5265}

# %% [markdown]
# ## Define all total events in test samples
# (which passed just l0 and goodgenB) using also empty events. Suppose that events which didn't pass **pass_2body** also were equal randomly divided into training and test samples

# %%
total_test_bck_events = (total_bck_events - total_bck_events_presel) // 2 + statistic_length(ds_test_bck)['Events']
total_test_signal_events = dict()
for mode in sig_train_modes_names:
    total_not_passed_signal = total_signal_events_by_mode[mode] - total_signal_events_by_mode_presel[mode]
    total_test_signal_events[mode] = total_not_passed_signal // 2 + \
        statistic_length(ds_test_signal[ds_test_signal['mode'] == mode])['Events']

# %%
print 'Bck total test events:', total_test_bck_events
'Signal total test events:', total_test_signal_events
# Out:
# Bck total test events: 55653
# ('Signal total test events:',
#  {11102003: 11181,
#   11104121: 10963,
#   11114001: 30491,
#   11114101: 18111,
#   11124001: 0,
#   11296013: 8491,
#   11536011: 6952,
#   11874004: 13728,
#   11874042: 2007,
#   12103035: 12585,
#   12103121: 11105,
#   12165106: 0,
#   12265042: 0,
#   12873002: 4730,
#   12873432: 0,
#   12875500: 0,
#   13102201: 0,
#   13102412: 15925,
#   13104012: 0,
#   13112001: 17474,
#   13144001: 27051,
#   13144020: 19608,
#   13246001: 18647,
#   13264021: 12605,
#   13512010: 21528,
#   13774002: 6297,
#   15164001: 3618,
#   15512011: 13967,
#   20000000: 0,
#   21263002: 4516,
#   23103110: 0,
#   25103000: 0,
#   25103110: 0,
#   27163002: 444,
#   27163400: 189,
#   27265001: 437,
#   27265101: 1090})

# %% [markdown]
# # Matrixnet training

# %%
from rep.estimators import EventFilterClassifier

# %%
ef_base = EventFilterClassifier(features=variables_base, dataset_name='hlt1_topo_feb', url_base='w80.h.cern.yandex.net',
                                iterations=5000, sync=False)
ef_base.fit(train, train['signal'])
# Out:
# EventFilterClassifier(auto_stop=None, baseline=None, command_line_params=None,
#            dataset_name='hlt2_topo_feb', dump_filename=None,
#            features=['n', 'm', 'mcor', 'chi2', 'sumpt', 'pt', 'eta', 'fdchi2', 'minpt', 'nlt16', 'ipchi2', 'n1trk'],
#            features_sample_rate_per_iteration=1.0, formula_name='EF',
#            intervals=64, iterations=5000, max_features_per_iteration=6,
#            password=None, regularization=0.01, sync=False,
#            training_fraction=0.5, url_base='w80.h.cern.yandex.net',
#            user=None)

# %%
ef_base.get_feature_importances().sort('effect')
# Out:
#           effect  efficiency  information
# chi2    0.320977       0.070     1.000000
# minpt   0.422126       0.097     0.953541
# pt      0.597763       0.139     0.935837
# nlt16   0.622374       1.000     0.135682
# fdchi2  0.906280       0.216     0.914481
# mcor    1.000000       0.219     0.995164

# %%
ef_add = EventFilterClassifier(features=variables_base + variables_additional,
                               dataset_name='hlt1_topo_feb_add', url_base='w80.h.cern.yandex.net',
                               iterations=5000, sync=False)
ef_add.fit(train, train['signal'])
# Out:
# EventFilterClassifier(auto_stop=None, baseline=None, command_line_params=None,
#            dataset_name='hlt1_topo_feb_add', dump_filename=None,
#            features=['mcor', 'chi2', 'pt', 'fdchi2', 'minpt', 'nlt16', 'm', 'fdr', 'sumpt', 'sumipchi2', 'eta'],
#            features_sample_rate_per_iteration=1.0, formula_name='EF',
#            intervals=64, iterations=5000, max_features_per_iteration=6,
#            password=None, regularization=0.01, sync=False,
#            training_fraction=0.5, url_base='w80.h.cern.yandex.net',
#            user=None)

# %%
ef_add.get_feature_importances().sort('effect')
# Out:
#              effect  efficiency  information
# pt         0.154133       0.032     0.921499
# chi2       0.287965       0.056     0.984679
# sumipchi2  0.341129       0.073     0.900901
# eta        0.391803       0.075     1.000000
# minpt      0.398354       0.081     0.938932
# fdr        0.419956       0.089     0.902352
# m          0.497158       0.096     0.986640
# sumpt      0.588165       0.122     0.919676
# fdchi2     0.637432       0.136     0.900470
# nlt16      0.697797       1.000     0.133603
# mcor       1.000000       0.195     0.979916

# %%
ef_base_weight = EventFilterClassifier(features=variables_base, dataset_name='hlt1_topo_feb_w', url_base='w80.h.cern.yandex.net',
                                       iterations=5000, sync=False)
labels = numpy.array(train['signal'])
sample_weight = numpy.ones(len(train))
sample_weight[labels == 0] *= 25
ef_base_weight.fit(train, labels, sample_weight=sample_weight)
# Out:
# EventFilterClassifier(auto_stop=None, baseline=None, command_line_params=None,
#            dataset_name='hlt1_topo_feb_w', dump_filename=None,
#            features=['mcor', 'chi2', 'pt', 'fdchi2', 'minpt', 'nlt16'],
#            features_sample_rate_per_iteration=1.0, formula_name='EF',
#            intervals=64, iterations=5000, max_features_per_iteration=6,
#            password=None, regularization=0.01, sync=False,
#            training_fraction=0.5, url_base='w80.h.cern.yandex.net',
#            user=None)

# %%
ef_base_weight.get_feature_importances().sort('effect')
# Out:
#           effect  efficiency  information
# nlt16   0.380295       1.000     0.135682
# chi2    0.451891       0.161     1.000000
# minpt   0.619592       0.232     0.953541
# fdchi2  0.654350       0.255     0.914481
# pt      0.675946       0.258     0.935837
# mcor    1.000000       0.358     0.995164

# %%
import cPickle
with open('models/mn_base_hlt1.pkl', 'w') as file_mn:
    cPickle.dump(ef_base, file_mn)
    
with open('models/mn_add_hlt1.pkl', 'w') as file_mn:
    cPickle.dump(ef_add, file_mn)
    
with open('models/mn_base_w_hlt1.pkl', 'w') as file_mn:
    cPickle.dump(ef_base_weight, file_mn)

# %%
estimators = {'base': ef_base, 'add features': ef_add, 'base + reweight': ef_base_weight}

# %% [markdown]
# ## Calculate thresholds on classifiers

# %%
thresholds = dict()
for name, cl in estimators.items():
    prob = cl.predict_proba(ds_test_bck)
    thr, result = calculate_thresholds(ds_test_bck, prob, total_test_bck_events, rates=[50000., 90000.])
    thresholds[name] = thr
    print name, result
# Out:
# base {50000.0: (0.8809502003113765, 2782, 0.049988320485867786), 90000.0: (0.2754905183426436, 5008, 0.08998616426787415)}
# base + reweight
#  {50000.0: (0.24509125247496197, 2782, 0.049988320485867786), 90000.0: (0.017455509742908996, 5008, 0.08998616426787415)}
# add features
#  {50000.0: (0.84869886280082574, 2782, 0.049988320485867786), 90000.0: (0.18422607547237629, 5008, 0.08998616426787415)}

# %% [markdown]
# ## Final efficiencies for each mode

# %%
from collections import defaultdict

# %%
# dict((name, rate): dict(mode: eff))
train_modes_eff = defaultdict(OrderedDict)
statistic = defaultdict(list)
for name, cl in estimators.items():
    for mode in sig_train_modes_names:
        sig_mode = ds_test_signal[ds_test_signal['mode'] == mode]
        if len(sig_mode) <= 0:
            continue
        statistic['mode'].append(mode)
        statistic['classifier'].append(name)
        statistic['name'].append('$' + Samples[str(mode)]['root'] + '$')
        sig_prediction = cl.predict_proba(sig_mode)[:, 1]
        sig_event_prediction = voting_for_event_svr(sig_mode['event_number'], sig_prediction)
        for rate, thr in thresholds[name].items():
            exist_sig = numpy.sum(sig_event_prediction >= thr)
            eff = exist_sig * 1. / total_test_signal_events[mode]
            statistic[rate].append(eff * 100.)
            train_modes_eff[(name, rate)]['$' + Samples[str(mode)]['root'] + '$\n' + str(mode)] = eff

# %%
from rep.plotting import BarComparePlot
BarComparePlot(train_modes_eff).plot(new_plot=True, figsize=(24, 6), ylabel='efficiency')
legend(bbox_to_anchor=(0.5, 1.2), loc='upper center', ncol=3)

# %%
pandas.DataFrame(statistic)
# Out:
#       50000.0    90000.0       classifier      mode  \
# 0   88.170493  89.061403             base  13144001
# 1   31.746032  35.449735             base  27163400
# 2   85.888953  86.565017             base  11536011
# 3   92.592156  93.192792             base  11296013
# 4   86.612443  87.481552             base  11114001
# 5   87.473225  87.822293             base  13264021
# 6   63.684677  65.854739             base  21263002
# 7   76.807611  77.484144             base  12873002
# 8   89.767791  90.808173             base  13246001
# 9   80.990948  81.800858             base  13774002
# 10  75.977104  76.272248             base  11102003
# 11  82.127733  82.373813             base  13112001
# 12  64.056113  64.432367             base  13512010
# 13  62.182287  62.812343             base  15512011
# 14  57.538462  58.147567             base  13102412
# 15  24.036697  28.073394             base  27265101
# 16   8.770824   9.671319             base  12103121
# 17  87.020604  87.836597             base  13144020
# 18  54.279279  56.081081             base  27163002
# 19  88.584854  88.999447             base  15164001
# 20  41.876430  46.681922             base  27265001
# 21  81.993007  82.386364             base  11874004
# 22  66.142124  67.108387             base  11114101
# 23  61.835264  62.519383             base  11104121
# 24  79.970105  80.568012             base  11874042
# 25  84.282876  84.688121             base  12103035
# 26  88.148312  89.065099  base + reweight  13144001
# 27  32.275132  35.449735  base + reweight  27163400
# 28  85.831415  86.565017  base + reweight  11536011
# 29  92.568602  93.192792  base + reweight  11296013
# ..        ...        ...              ...       ...
# 48  66.108995  67.108387  base + reweight  11114101
# 49  61.844386  62.519383  base + reweight  11104121
# 50  79.970105  80.568012  base + reweight  11874042
# 51  84.282876  84.688121  base + reweight  12103035
# 52  88.617796  89.065099     add features  13144001
# 53  32.275132  35.449735     add features  27163400
# 54  86.032796  86.579402     add features  11536011
# 55  92.674597  93.192792     add features  11296013
# 56  86.861697  87.497950     add features  11114001
# 57  87.536692  87.822293     add features  13264021
# 58  63.396811  65.854739     add features  21263002
# 59  76.934461  77.505285     add features  12873002
# 60  90.052019  90.824261     add features  13246001
# 61  81.149754  81.800858     add features  13774002
# 62  76.111260  76.272248     add features  11102003
# 63  82.276525  82.368090     add features  13112001
# 64  64.102564  64.427722     add features  13512010
# 65  62.232405  62.826663     add features  15512011
# 66  57.701727  58.147567     add features  13102412
# 67  24.311927  28.073394     add features  27265101
# 68   9.058982   9.671319     add features  12103121
# 69  87.239902  87.851897     add features  13144020
# 70  53.378378  56.081081     add features  27163002
# 71  88.529574  89.027087     add features  15164001
# 72  42.791762  46.453089     add features  27265001
# 73  82.131410  82.386364     add features  11874004
# 74  66.357462  67.113909     add features  11114101
# 75  61.990331  62.519383     add features  11104121
# 76  80.019930  80.617838     add features  11874042
# 77  84.338498  84.680175     add features  12103035
#
#                                                                                                                     name
# 0                                                       $B_{s}^{0} \rightarrow \psi(1S)[\mu^{+}\mu^{-}]\phi[K^{+}K^{-}]$
# 1                                                           $D^{*+}(2010) \rightarrow D^{0}[K^{-}\pi^{+}\pi^{0}]\pi^{+}$
# 2   $B^{0} \rightarrow D^{*-}[\pi^{-}\bar{D}^{0}[K^{+}\pi^{-}]\tau^{+}[\pi^{+}\pi^{+}\pi^{-}\bar{\nu}_{\tau}]\nu_{\tau}$
# 3                                               $B^{0} \rightarrow D^{+}[K^{-}\pi^{+}\pi^{+}]D^{-}[K^{+}\pi^{-}\pi^{-}]$
# 4                                                                  $B^{0} \rightarrow K^{*}[K^{+}\pi^{-}]\mu^{+}\mu^{-}$
# 5                                                            $B_{s}^{0} \rightarrow D_{s}^{-}[K^{+}K^{-}\pi^{-}]\pi^{+}$
# 6                                                                                  $D^{+} \rightarrow K^{-}K^{+}\pi^{+}$
# 7                                                          $B^{+} \rightarrow \bar{D}^{0}[K^{+}\pi^{-}]\mu^{+}\nu_{\mu}$
# 8                                               $B_{s}^{0} \rightarrow \psi(1S)[\mu^{+}\mu^{-}]K^{+}K^{-}\pi^{+}\pi^{-}$
# 9                                                   $B_{s}^{0} \rightarrow D_{s}^{-}[K^{+}K^{-}\pi^{-}]\mu^{+}\nu_{\mu}$
# 10                                                                                      $B^{0} \rightarrow K^{-}\pi^{+}$
# 11                                                                                $B_{s}^{0} \rightarrow \mu^{+}\mu^{-}$
# 12                                                                         $B_{s}^{0} \rightarrow K^{-}\mu^{+}\nu_{\mu}$
# 13                                                             $\Lambda_{b}^{0} \rightarrow p^{+}\mu^{-}\bar{\nu}_{\mu}$
# 14                                                                             $B_{s}^{0} \rightarrow K^{-}K^{+}\pi^{0}$
# 15                                              $D^{*+}(2010) \rightarrow D^{0}[K_{S}[\pi^{+}\pi^{-}]K^{+}K^{-}]\pi^{+}$
# 16                                                                        $B^{+} \rightarrow K^{+}K_{S}[\pi^{+}\pi^{-}]$
# 17                                                      $B_{s}^{0} \rightarrow \psi(2S)[\mu^{+}\mu^{-}]\phi[K^{+}K^{-}]$
# 18                                                                   $D^{*+}(2010) \rightarrow D^{0}[K^{+}K^{-}]\pi^{+}$
# 19                                               $\Lambda_{b}^{0} \rightarrow \Lambda_{c}^{+}[p^{+}K^{+}\pi^{-}]\pi^{-}$
# 20                                                     $D^{*+}(2010) \rightarrow D^{0}[K^{+}K^{-}\pi^{+}\pi^{-}]\pi^{+}$
# 21                                          $B^{0} \rightarrow D^{*-}[\pi^{-}\bar{D}^{0}[K^{+}\pi^{-}]]\mu^{+}\nu_{\mu}$
# 22                                                           $B^{0} \rightarrow K_{S}^{0}[\pi^{+}\pi^{-}]\mu^{+}\mu^{-}$
# 23                                                           $B^{0} \rightarrow K_{S}^{0}[\pi^{+}\pi^{-}]\pi^{+}\pi^{-}$
# 24                                                        $B^{0} \rightarrow D^{-}[K^{+}\pi^{-}\pi^{-}]\mu^{+}\nu_{\mu}$
# 25                                                                                 $B^{+} \rightarrow \pi^{+}K^{-}K^{+}$
# 26                                                      $B_{s}^{0} \rightarrow \psi(1S)[\mu^{+}\mu^{-}]\phi[K^{+}K^{-}]$
# 27                                                          $D^{*+}(2010) \rightarrow D^{0}[K^{-}\pi^{+}\pi^{0}]\pi^{+}$
# 28  $B^{0} \rightarrow D^{*-}[\pi^{-}\bar{D}^{0}[K^{+}\pi^{-}]\tau^{+}[\pi^{+}\pi^{+}\pi^{-}\bar{\nu}_{\tau}]\nu_{\tau}$
# 29                                              $B^{0} \rightarrow D^{+}[K^{-}\pi^{+}\pi^{+}]D^{-}[K^{+}\pi^{-}\pi^{-}]$
# ..                                                                                                                   ...
# 48                                                           $B^{0} \rightarrow K_{S}^{0}[\pi^{+}\pi^{-}]\mu^{+}\mu^{-}$
# 49                                                           $B^{0} \rightarrow K_{S}^{0}[\pi^{+}\pi^{-}]\pi^{+}\pi^{-}$
# 50                                                        $B^{0} \rightarrow D^{-}[K^{+}\pi^{-}\pi^{-}]\mu^{+}\nu_{\mu}$
# 51                                                                                 $B^{+} \rightarrow \pi^{+}K^{-}K^{+}$
# 52                                                      $B_{s}^{0} \rightarrow \psi(1S)[\mu^{+}\mu^{-}]\phi[K^{+}K^{-}]$
# 53                                                          $D^{*+}(2010) \rightarrow D^{0}[K^{-}\pi^{+}\pi^{0}]\pi^{+}$
# 54  $B^{0} \rightarrow D^{*-}[\pi^{-}\bar{D}^{0}[K^{+}\pi^{-}]\tau^{+}[\pi^{+}\pi^{+}\pi^{-}\bar{\nu}_{\tau}]\nu_{\tau}$
# 55                                              $B^{0} \rightarrow D^{+}[K^{-}\pi^{+}\pi^{+}]D^{-}[K^{+}\pi^{-}\pi^{-}]$
# 56                                                                 $B^{0} \rightarrow K^{*}[K^{+}\pi^{-}]\mu^{+}\mu^{-}$
# 57                                                           $B_{s}^{0} \rightarrow D_{s}^{-}[K^{+}K^{-}\pi^{-}]\pi^{+}$
# 58                                                                                 $D^{+} \rightarrow K^{-}K^{+}\pi^{+}$
# 59                                                         $B^{+} \rightarrow \bar{D}^{0}[K^{+}\pi^{-}]\mu^{+}\nu_{\mu}$
# 60                                              $B_{s}^{0} \rightarrow \psi(1S)[\mu^{+}\mu^{-}]K^{+}K^{-}\pi^{+}\pi^{-}$
# 61                                                  $B_{s}^{0} \rightarrow D_{s}^{-}[K^{+}K^{-}\pi^{-}]\mu^{+}\nu_{\mu}$
# 62                                                                                      $B^{0} \rightarrow K^{-}\pi^{+}$
# 63                                                                                $B_{s}^{0} \rightarrow \mu^{+}\mu^{-}$
# 64                                                                         $B_{s}^{0} \rightarrow K^{-}\mu^{+}\nu_{\mu}$
# 65                                                             $\Lambda_{b}^{0} \rightarrow p^{+}\mu^{-}\bar{\nu}_{\mu}$
# 66                                                                             $B_{s}^{0} \rightarrow K^{-}K^{+}\pi^{0}$
# 67                                              $D^{*+}(2010) \rightarrow D^{0}[K_{S}[\pi^{+}\pi^{-}]K^{+}K^{-}]\pi^{+}$
# 68                                                                        $B^{+} \rightarrow K^{+}K_{S}[\pi^{+}\pi^{-}]$
# 69                                                      $B_{s}^{0} \rightarrow \psi(2S)[\mu^{+}\mu^{-}]\phi[K^{+}K^{-}]$
# 70                                                                   $D^{*+}(2010) \rightarrow D^{0}[K^{+}K^{-}]\pi^{+}$
# 71                                               $\Lambda_{b}^{0} \rightarrow \Lambda_{c}^{+}[p^{+}K^{+}\pi^{-}]\pi^{-}$
# 72                                                     $D^{*+}(2010) \rightarrow D^{0}[K^{+}K^{-}\pi^{+}\pi^{-}]\pi^{+}$
# 73                                          $B^{0} \rightarrow D^{*-}[\pi^{-}\bar{D}^{0}[K^{+}\pi^{-}]]\mu^{+}\nu_{\mu}$
# 74                                                           $B^{0} \rightarrow K_{S}^{0}[\pi^{+}\pi^{-}]\mu^{+}\mu^{-}$
# 75                                                           $B^{0} \rightarrow K_{S}^{0}[\pi^{+}\pi^{-}]\pi^{+}\pi^{-}$
# 76                                                        $B^{0} \rightarrow D^{-}[K^{+}\pi^{-}\pi^{-}]\mu^{+}\nu_{\mu}$
# 77                                                                                 $B^{+} \rightarrow \pi^{+}K^{-}K^{+}$
#
# [78 rows x 5 columns]

# %% [markdown]
# ## Classification report using svrs

# %%
from rep.data import LabeledDataStorage, DataStorage
from rep.report import ClassificationReport
lds = LabeledDataStorage(DataStorage(pandas.concat([ds_test_signal, ds_test_bck])), 'signal')
report = ClassificationReport(estimators, lds)

# %% [markdown]
# ### roc curve

# %%
report.roc().plot_plotly()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~tata.antares/1001/755/395" height="420" width="780"></iframe>

# %% [markdown]
# ### efficiencies for each mode per iterations

# %% [markdown]
# #### Generate eff metrics

# %%
mode_metrics = dict()
for mode in sig_train_modes_names:
    mode_metrics[mode] = dict()
    for rate in [50000., 90000.]:
        mode_metrics[mode][rate] = generate_topo_metric(ds_test_bck, ds_test_signal[ds_test_signal['mode'] == mode], 
                                                        total_test_bck_events, total_test_signal_events[mode], rate)

# %%
def generate_select_mode(mode):
    def select_mode(pd):
        result = numpy.zeros(len(pd), dtype=bool)
        result[numpy.array(pd['mode']) == mode] = True
        result[numpy.array(pd['signal']) == 0] = True
        return result
    return select_mode

# %%
staged_eff_plots = []
for mode in sig_train_modes_names:
    eff_metrics = OrderedDict()
    eff_metrics['mode {}, rate {}, eff'.format(mode, 90000.)] = mode_metrics[mode][90000.]
    eff_metrics['mode {}, rate {}, eff'.format(mode, 50000.)] = mode_metrics[mode][50000.]
    select_mode = generate_select_mode(mode)
    if len(ds_test_signal[ds_test_signal['mode'] == mode]) <= 0:
        continue
    staged_eff_plots.append(report.learning_curve(eff_metrics, mask=select_mode, steps=10))

# %%
for elem in staged_eff_plots:
    elem.plot()

# %% [markdown]
# ## Classification report using events for 'add features' model

# %%
test_all = pandas.concat([ds_test_signal, ds_test_bck])
pred_all = ef_add.predict_proba(test_all)[:, 1]

# %%
from sklearn.metrics import roc_auc_score, roc_curve
fpr, tpr, _ = roc_curve(test_all['signal'], pred_all)
print 'AUC', roc_auc_score(test_all['signal'], pred_all)
# Out:
# AUC
# 0.936682703582

# %%
plot(fpr, tpr)
xlim(0, 0.09)
# Out:
# (0, 0.09)

# %%
plot(fpr, tpr)
xlim(0, 0.05)
# Out:
# (0, 0.05)

# %% [markdown]
# # Reload models

# %%
import cPickle
with open('models/mn_base_hlt1.pkl', 'r') as file_mn:
    ef_base = cPickle.load(file_mn)
    
with open('models/mn_add_hlt1.pkl', 'r') as file_mn:
    ef_add = cPickle.load(file_mn)

with open('models/mn_base_w_hlt1.pkl', 'r') as file_mn:
    ef_base_weight = cPickle.load(file_mn)
